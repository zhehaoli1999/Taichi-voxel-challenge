# %%
import matplotlib.pyplot as plt 
import numpy as np 
from matplotlib import cm

S = lambda x: 3*x**2 - 2*x**3

x = np.arange(-1, 1, 0.01)
y = np.arange(-1, 1, 0.01)
X, Y = np.meshgrid(x, y)

a = 0.1
b = 0.2
c = 0.4
d = 0.4 

# f = lambda x,y: a + (b-a)*S(x) + (c-a) * S(y) + (a - b - c + d)*S(x)*S(y)
# f1 = lambda x,y: 0.5 - (0.5 * x-0.6)**2 - (0.5 * y-0.6)**2 
#f2 = lambda x,y: 1.+-0.2*(x + 1)**2 - 0.2* (y+1)
#f = lambda x,y: f1(x,y) + f2(x,y)
# f = lambda x, y: (0.2* np.sin(2.1*x)/x + 0.2* np.sin(1.6*y)/y) 
f = lambda x ()

Z = np.array(f(X, Y))

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.set_zlim(-1., 1.)
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
